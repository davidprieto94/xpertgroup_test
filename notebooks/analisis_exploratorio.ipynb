# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Ruta de los datos limpios
cleaned_data_file = "../outputs/cleaned_data.csv"
data = pd.read_csv(cleaned_data_file)

# Resumen estadístico
print("Resumen estadístico:")
print(data.describe())

# Gráficos básicos
# Distribución de una variable numérica
sns.histplot(data['Price'], kde=True)
plt.title("Distribución de Precios")
plt.savefig("../outputs/distribucion_precios.png")
plt.show()

# Correlaciones
correlation = data.corr()
sns.heatmap(correlation, annot=True, cmap="coolwarm")
plt.title("Matriz de Correlación")
plt.savefig("../outputs/matriz_correlacion.png")
plt.show()
# Out:
# Resumen estadístico:
#              Price
# count  1000.000000
# mean    106.289000
# std      53.695444
# min      10.000000
# 25%      59.750000
# 50%     108.000000
# 75%     150.000000
# max     199.000000
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 21
#      18 plt.show()
#      20 # Correlaciones
# ---> 21 correlation = data.corr()
#      22 sns.heatmap(correlation, annot=True, cmap="coolwarm")
#      23 plt.title("Matriz de Correlación")
#
# File c:\Users\david\anaconda3\envs\pythonProject\Lib\site-packages\pandas\core\frame.py:11049, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11047 cols = data.columns
#   11048 idx = cols.copy()
# > 11049 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11051 if method == "pearson":
#   11052     correl = libalgos.nancorr(mat, minp=min_periods)
#
# ...
